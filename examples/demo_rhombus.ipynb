# %% [markdown]
# # Initialization

# %%
import sys  
sys.path.insert(0, '/Users/xyy/PycharmProjects/scqubits')

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

import scqubits as qubit

import numpy as np
import matplotlib.pyplot as plt

# %%
rhombus = qubit.Rhombus(
    EJ1 = 30.0,
    EJ2 = 30.0,
    EC1 = 1,
    EC2 = 1,
    ECS = 1,
    ng1 = 0.0,
    ng2 = 0.0,
    ngs = 0.0,
    flux = 0.5,
    kbt = 3,
    N1 = 10,
    N2 = 10,
    NS = 10
)

# %%
rhombus._evals_calc(2)
# Out:
# array([1.48341554, 1.928262  ])

# %%
esys = rhombus.eigensys()
fig, axes = rhombus.plot_phi_1_phi_2_wavefunction(esys, which=0, mode='abs', zero_calibrate=True, figsize=(4,4))
axes.set_ylabel(r'$\phi_1$')
axes.set_xlabel(r'$\phi_2$')
fig, axes = rhombus.plot_phi_1_theta_wavefunction(esys, which=0, mode='abs', zero_calibrate=True, figsize=(4,4))
axes.set_ylabel(r'$\phi_1$')
axes.set_xlabel(r'$\phi_2$')
fig, axes = rhombus.plot_phi_2_theta_wavefunction(esys, which=0, mode='abs', zero_calibrate=True, figsize=(4,4))
axes.set_ylabel(r'$\phi_1$')
axes.set_xlabel(r'$\phi_2$')
# Out:
# Text(0.5, 0, '$\\phi_2$')

# %%
rhombus.plot_potential()
# Out:
# (<Figure size 600x600 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fa8818668d0>)

# %%
ng1_list = np.linspace(0, .5, 20)
rhombus.plot_evals_vs_paramvals('ngs', ng1_list, evals_count=4, subtract_ground=True, figsize=(4,4));

# %%
ng1_list = np.linspace(0, .5, 20)
rhombus.plot_evals_vs_paramvals('ng1', ng1_list, evals_count=4, subtract_ground=True, figsize=(4,4));

# %%
esys = rhombus.eigensys()
ft_wfnc0 = rhombus.ft_wavefunction(esys, which=0)
ft_wfnc1 = rhombus.ft_wavefunction(esys, which=1)

# %%
rhombus.plot_n_theta_n_phi_2_wavefunction(ft_wfnc0, mode='abs', zero_calibrate=True, figsize=(4,4))
rhombus.plot_n_theta_n_phi_2_wavefunction(ft_wfnc1, mode='abs', zero_calibrate=True, figsize=(4,4))
# Out:
# (<Figure size 600x600 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fa881719850>)

# %%
rhombus.plot_n_phi_1_n_theta_wavefunction(ft_wfnc0, mode='abs', zero_calibrate=True,figsize=(4,4))
rhombus.plot_n_phi_1_n_theta_wavefunction(ft_wfnc1, mode='abs', zero_calibrate=True,figsize=(4,4))
# Out:
# (<Figure size 600x600 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fa88304c390>)

# %%
rhombus.plot_n_phi_1_n_phi_2_wavefunction(ft_wfnc0, mode='abs', zero_calibrate=True,figsize=(4,4))
rhombus.plot_n_phi_1_n_phi_2_wavefunction(ft_wfnc1, mode='abs', zero_calibrate=True,figsize=(4,4))
# Out:
# (<Figure size 600x600 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fa881c52590>)

# %%
rhombus.print_noise()
# Out:
# ...
#  T2_ng1= [3.36597039e-06]
#  T2_ng2= [3.36597039e-06]
#  T2_ngs= [3.36597102e-06]
#  T2_ej1= [0.08196595]
#  T2_ej2= [0.08196596]

# %%
rhombus.print_noise()
# Out:
# ...
#  T2_ng1= [5.89852646e-07]
#  T2_ng2= [5.89852646e-07]
#  T2_ngs= [5.89852646e-07]
#  T2_ej1= [2.31500345]
#  T2_ej2= [0.27448624]

# %%
rhombus.noise_analysis('ECS', np.linspace(0.1,5,20))
