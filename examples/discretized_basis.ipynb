# %%
import sys  
sys.path.insert(0, '/Users/xyy/PycharmProjects/scqubits')
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

import scqubits as qubit

import numpy as np
import matplotlib.pyplot as plt

# %%
dcpd_qubit = qubit.Dcpd(
    EJ = 5,
    EC = 1.7,
    EL = 0.2,
    ELA = 0.2,
    x = 1,
    flux = 0.,
    fluxa = 0.5,
    kbt = 20
)

# %%
np.diff(dcpd_qubit._evals_calc(10))
# Out:
# array([3.36593274e-02, 1.19964442e+00, 1.89953071e-02, 1.56263643e+00,
#        1.79837192e-02, 9.55673190e-01, 1.08022742e-03, 4.01943082e-03,
#        5.79681480e-03])

# %%
dcpd_qubit.print_noise(g_state=0, e_state=2)
# Out:
# ...
# T2_current = 13.583566538542877  ms
#  T2_flux = 13.982871862365876  ms
#  T2_flux_a = 48.068301212070914  ms
#  T1_cap = 3.333044058673493  ms
#  T1_Purcell = 780.1942304050781  ms
#  T1_ind = 2.4123834308641667  ms
#  T1 = 1.3969688585822277  ms
#  T2 = 1.9089217140532178  ms

# %%
fig, axes = dcpd_qubit.plot_potential(contour_vals=20, figsize=(4,4))
axes.set_ylabel(r'$\phi$')
axes.set_xlabel(r'$\varphi$')
axes.set_xticks([-np.pi, 0, np.pi, 2*np.pi])
axes.set_xticklabels(['-$\pi$', '$0$', '$\pi$', '$2\pi$'])
axes.set_yticks([-np.pi, np.pi])
axes.set_yticklabels(['-$\pi$', '$\pi$']);

# %%
dcpd_qubit.plot_evals_vs_paramvals('EJ',np.linspace(4.9,5.1,20), evals_count=10, subtract_ground=True)
# Out:
# ...
# (<Figure size 900x600 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7ff0e5af67d0>)

# %%
dcpd_qubit.fluxa = 0.5
dcpd_qubit.plot_evals_vs_paramvals('flux',np.linspace(-0.1,0.1,20), evals_count=10, subtract_ground=True)
# Out:
# ...
# (<Figure size 900x600 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f9c4875ba90>)

# %%
dcpd_qubit.fluxa = 0.5
dcpd_qubit.plot_evals_vs_paramvals('flux',np.linspace(-0.1,0.6,40), evals_count=10, subtract_ground=True)
# Out:
# ...
# (<Figure size 900x600 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f9e3e7f9310>)

# %%
dcpd_qubit.flux = 0
dcpd_qubit.plot_evals_vs_paramvals('fluxa',np.linspace(0.4,0.6,20), evals_count=10, subtract_ground=True)
# Out:
# ...
# (<Figure size 900x600 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f9c4919ad10>)

# %%
esys = dcpd_qubit.eigensys(evals_count=10)
fig, axes = dcpd_qubit.plot_phi_varphi_wavefunction(esys, which=0, mode='real', zero_calibrate=True, figsize=(4,4))
axes.set_ylabel(r'$\phi$')
axes.set_xlabel(r'$\varphi$')
axes.set_xticks([-np.pi, 0, np.pi, 2*np.pi])
axes.set_xticklabels(['-$\pi$', '$0$', '$\pi$', '$2\pi$'])
axes.set_yticks([-np.pi, np.pi])
axes.set_yticklabels(['-$\pi$', '$\pi$'])
fig, axes = dcpd_qubit.plot_phi_varphi_wavefunction(esys, which=1, mode='real', zero_calibrate=True, figsize=(4,4))
axes.set_ylabel(r'$\phi$')
axes.set_xlabel(r'$\varphi$')
axes.set_xticks([-np.pi, 0, np.pi, 2*np.pi])
axes.set_xticklabels(['-$\pi$', '$0$', '$\pi$', '$2\pi$'])
axes.set_yticks([-np.pi, np.pi])
axes.set_yticklabels(['-$\pi$', '$\pi$'])
fig, axes = dcpd_qubit.plot_phi_varphi_wavefunction(esys, which=2, mode='real', zero_calibrate=True, figsize=(4,4))
axes.set_ylabel(r'$\phi$')
axes.set_xlabel(r'$\varphi$')
axes.set_xticks([-np.pi, 0, np.pi, 2*np.pi])
axes.set_xticklabels(['-$\pi$', '$0$', '$\pi$', '$2\pi$'])
axes.set_yticks([-np.pi, np.pi])
axes.set_yticklabels(['-$\pi$', '$\pi$'])
fig, axes = dcpd_qubit.plot_phi_varphi_wavefunction(esys, which=3, mode='real', zero_calibrate=True, figsize=(4,4))
axes.set_ylabel(r'$\phi$')
axes.set_xlabel(r'$\varphi$')
axes.set_xticks([-np.pi, 0, np.pi, 2*np.pi])
axes.set_xticklabels(['-$\pi$', '$0$', '$\pi$', '$2\pi$'])
axes.set_yticks([-np.pi, np.pi])
axes.set_yticklabels(['-$\pi$', '$\pi$'])
fig, axes = dcpd_qubit.plot_phi_varphi_wavefunction(esys, which=4, mode='real', zero_calibrate=True, figsize=(4,4))
axes.set_ylabel(r'$\phi$')
axes.set_xlabel(r'$\varphi$')
axes.set_xticks([-np.pi, 0, np.pi, 2*np.pi])
axes.set_xticklabels(['-$\pi$', '$0$', '$\pi$', '$2\pi$'])
axes.set_yticks([-np.pi, np.pi])
axes.set_yticklabels(['-$\pi$', '$\pi$'])
fig, axes = dcpd_qubit.plot_phi_varphi_wavefunction(esys, which=5, mode='real', zero_calibrate=True, figsize=(4,4))
axes.set_ylabel(r'$\phi$')
axes.set_xlabel(r'$\varphi$')
axes.set_xticks([-np.pi, 0, np.pi, 2*np.pi])
axes.set_xticklabels(['-$\pi$', '$0$', '$\pi$', '$2\pi$'])
axes.set_yticks([-np.pi, np.pi])
axes.set_yticklabels(['-$\pi$', '$\pi$'])
fig, axes = dcpd_qubit.plot_phi_varphi_wavefunction(esys, which=6, mode='real', zero_calibrate=True, figsize=(4,4))
axes.set_ylabel(r'$\phi$')
axes.set_xlabel(r'$\varphi$')
axes.set_xticks([-np.pi, 0, np.pi, 2*np.pi])
axes.set_xticklabels(['-$\pi$', '$0$', '$\pi$', '$2\pi$'])
axes.set_yticks([-np.pi, np.pi])
axes.set_yticklabels(['-$\pi$', '$\pi$'])
fig, axes = dcpd_qubit.plot_phi_varphi_wavefunction(esys, which=7, mode='real', zero_calibrate=True, figsize=(4,4))
axes.set_ylabel(r'$\phi$')
axes.set_xlabel(r'$\varphi$')
axes.set_xticks([-np.pi, 0, np.pi, 2*np.pi])
axes.set_xticklabels(['-$\pi$', '$0$', '$\pi$', '$2\pi$'])
axes.set_yticks([-np.pi, np.pi])
axes.set_yticklabels(['-$\pi$', '$\pi$'])
fig, axes = dcpd_qubit.plot_phi_varphi_wavefunction(esys, which=8, mode='real', zero_calibrate=True, figsize=(4,4))
axes.set_ylabel(r'$\phi$')
axes.set_xlabel(r'$\varphi$')
axes.set_xticks([-np.pi, 0, np.pi, 2*np.pi])
axes.set_xticklabels(['-$\pi$', '$0$', '$\pi$', '$2\pi$'])
axes.set_yticks([-np.pi, np.pi])
axes.set_yticklabels(['-$\pi$', '$\pi$']);

# %%
data = dcpd_qubit.get_matelements_vs_paramvals('phi_operator', 'ph',[0],evals_count=10)

# %%
np.abs(data.matrixelem_table[0,0,:])
# Out:
# array([1.98105421e-15, 9.14198105e-16, 1.06727413e+00, 1.53472705e-13,
#        1.46708774e-15, 2.92035326e-15, 2.01423659e-13, 4.27762269e-02,
#        3.40874233e-01, 1.67428930e-13])
