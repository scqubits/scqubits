# %% [markdown]
# # Initialization

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

import scqubits as scq
import scqubits.utils.plotting as plot

import numpy as np

# %% [markdown]
# # Fluxonium qubit

# %% [markdown]
# $H_\text{fl}=-4E_\text{C}\partial_\phi^2-E_\text{J}\cos(\phi-\varphi_\text{ext}) +\frac{1}{2}E_L\phi^2$

# %%
fluxonium = scq.Fluxonium(
    EJ=8.9,
    EC=2.5,
    EL=0.5,
    cutoff = 110,
    flux = 0.5
)

# %%
fluxonium = scq.Fluxonium.create()
# Out:
# HBox(children=(VBox(children=(HBox(children=(Label(value='EJ [GHz]'), FloatText(value=8.9, layout=Layout(width…
# Output()

# %%
print(fluxonium)
# Out:
# FLUXONIUM
#  ———— PARAMETERS ————
# EJ	: 8.9
# EC	: 2.5
# EL	: 0.5
# flux	: 0.0
# cutoff	: 110
# truncated_dim	: 10
# Hilbert space dimension	: 110

# %%
fluxonium.eigenvals()
# Out:
# array([-4.28338463,  4.47506063,  4.69616798,  6.71864972, 12.64960539,
#        15.28847499])

# %%
fluxonium.eigenvals()
# Out:
# array([-4.28338463,  4.47506063,  4.69616798,  6.71864972, 12.64960539,
#        15.28847499])

# %%
flux_list = np.linspace(-0.5, 0.5, 151)
fluxonium.plot_evals_vs_paramvals('flux', flux_list, evals_count=8);
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Spectral data', max=151.0, style=ProgressStyle(descriptio…
# WARNING:matplotlib.font_manager:findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
flux_list = np.linspace(-0.5, 0.5, 151)
fluxonium.plot_evals_vs_paramvals('flux', flux_list, evals_count=8);
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Spectral data', max=151.0, style=ProgressStyle(descriptio…

# %%
fluxonium.plot_evals_vs_paramvals('flux', flux_list, evals_count=9, subtract_ground=True);
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Spectral data', max=151.0, style=ProgressStyle(descriptio…

# %%
fluxonium.flux = 0.25
fluxonium.plot_wavefunction(esys=None, which=[0, 1, 2, 3, 5, 6], mode='real');
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
fluxonium.plot_wavefunction(esys=None, which=[0, 1, 2, 3], mode='real');

# %% [markdown]
# ### Matrix elements

# %%
phimat = fluxonium.matrixelement_table('phi_operator', evals_count=10)
plot.matrix(phimat);

# %%
fluxonium.plot_matrixelements('n_operator', evals_count=16);

# %%
fluxonium.cos_phi_operator(1/2, 2)
# Out:
# array([[ 0.63578342+0.00000000e+00j, -0.05109943+5.55111512e-16j,
#         -0.41285602-1.82145965e-16j, ...,  0.00952914+1.08853898e-16j,
#          0.00579106+2.45029691e-17j,  0.00544689-1.78297047e-16j],
#        [-0.05109943-5.55111512e-16j,  0.09263713+0.00000000e+00j,
#         -0.02411404-7.49400542e-16j, ...,  0.01401083+3.68628739e-18j,
#          0.01103929+2.68882139e-17j,  0.0065551 -2.08166817e-17j],
#        [-0.41285602+1.82145965e-16j, -0.02411404+7.49400542e-16j,
#         -0.17820847+0.00000000e+00j, ...,  0.01523419-1.34441069e-17j,
#          0.01603222-5.48606299e-17j,  0.01073462+8.06646416e-17j],
#        ...,
#        [ 0.00952914-1.08853898e-16j,  0.01401083-3.68628739e-18j,
#          0.01523419+1.34441069e-17j, ..., -0.13788937+0.00000000e+00j,
#         -0.00284549-4.85722573e-17j, -0.05123562+1.38777878e-17j],
#        [ 0.00579106-2.45029691e-17j,  0.01103929-2.68882139e-17j,
#          0.01603222+5.48606299e-17j, ..., -0.00284549+4.85722573e-17j,
#         -0.07366074+0.00000000e+00j,  0.00476224+4.16333634e-17j],
#        [ 0.00544689+1.78297047e-16j,  0.0065551 +2.08166817e-17j,
#          0.01073462-8.06646416e-17j, ..., -0.05123562-1.38777878e-17j,
#          0.00476224-4.16333634e-17j, -0.01394903+0.00000000e+00j]])
