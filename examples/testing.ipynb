# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

import scqubits.testing as tst
tst.run()
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.7.4, pytest-5.3.2, py-1.8.0, pluggy-0.12.0 -- C:\Users\drjen\Miniconda3\python.exe
# cachedir: .pytest_cache
# rootdir: c:\users\drjen\pycharmprojects\scqubits
# collecting ... collected 47 items
#
# ..\scqubits\tests\test_fluxonium.py::TestFluxonium::test_eigenvals PASSED                                        [  2%]
# ..\scqubits\tests\test_fluxonium.py::TestFluxonium::test_eigenvecs PASSED                                        [  4%]
# ..\scqubits\tests\test_fluxonium.py::TestFluxonium::test_plot_evals_vs_paramvals
# PASSED                          [  6%]
# ..\scqubits\tests\test_fluxonium.py::TestFluxonium::test_get_spectrum_vs_paramvals PASSED                        [  8%]
# ..\scqubits\tests\test_fluxonium.py::TestFluxonium::test_matrixelement_table PASSED                              [ 10%]
# ...
